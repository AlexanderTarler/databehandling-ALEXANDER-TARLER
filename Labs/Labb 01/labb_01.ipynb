# %% [markdown]
# # Labb 01 - Assignment Dataprocessing

# %% [markdown]
# ### Introduction
# In this laboration I will use pandas and matplotlib.pyplot to process and present data from 777 colleges.
#
# Each section will have a short explanation of what it does. The last section will also present a brief summary of my findings as well as how I arrived to them. I first aimed to write down the instructions from every task together with their descriptions, but I chose not to due to the text-bloat.

# %% [markdown]
# #### Task (a)
#
# As shown below, I import what I need (pandas, as well as matplotlib.pyplot for future use) and then read the "College.csv"-file.

# %%
# a

import pandas as pd 
import matplotlib.pyplot as plt

college = pd.read_csv("College.csv")
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# #### Task (b)
#
# For task (b) I used to code provided in the task description and renamed the column that needed renaming. I also set the index to "College", as required.

# %%
# b

college2 = pd.read_csv("College.csv", index_col=0)
college3 = college.rename({"Unnamed: 0":"College"}, axis=1)
college3 = college3.set_index("College")
college = college3

# %% [markdown]
# #### Task (c)
#
# Using "college.describe()" allows me to see a lot of information about the data I am processing.

# %%
# c

college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# #### Task (d)
#
# In this task I use the scatter_matrix method to create the scatterplot we seek. I decided to call the columns directly as a list instead of creating a separate list and then using it to call the method.

# %%
# d

pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# #### Task (e)
#
# Since I have never properly used a boxplot before this task was a bit challenging - it was hard for me to properly "read" it until I had read up on it some more.
#
# The plot shows use that "Private" colleges generally take more outstate tuition than their "Public" counterparts.

# %%
# e

college.boxplot(column='Outstate', by='Private', grid=False)

plt.title('Outstate Tuition by Private vs Public')
plt.suptitle('')  
plt.xlabel('Private')
plt.ylabel('Outstate Tuition')
plt.show()

# %% [markdown]
# #### Task (f)
#
# In the code below I used both pandas and matplotlib.pyplot to show that the "Elite" colleges are, in general, more expensive when it comes to out-of-state tuition.

# %%
# f

college["Elite"] = pd.cut(college["Top10perc"], [0, 50, 100], labels=["No", "Yes"])

print(college["Elite"].value_counts())

college.boxplot(column='Outstate', by='Elite', grid=False)
plt.title('Outstate Tuition by Elite Status')
plt.suptitle('')  
plt.xlabel('Elite')
plt.ylabel('Outstate Tuition')
plt.show()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %% [markdown]
# #### Task (g)
#
# For this task I chose to use the variables "Apps", "Accept", "Enroll" and "Grad.Rate" to see if the data would show any correlation between the four variables.

# %%
# g

variables = ["Apps", "Accept", "Enroll", "Grad.Rate"]
titles = ["Applications (10 bins)", "Acceptances (15 bins)", "Enrollment (20 bins)", "Graduation Rate (25 bins)"]
bins = [10, 15, 20, 25]
x_labels = ["Number of Applications", "Number of Acceptances", "Number of Enrollments", "Graduation Rate (%)"]

fig, axes = plt.subplots(2, 2, figsize=(10, 8))

for i, ax in enumerate(axes.flatten()):
    college[variables[i]].plot.hist(bins=bins[i], ax=ax, title=titles[i])
    ax.set_xlabel(x_labels[i])
    ax.set_ylabel("Number of schools")

plt.tight_layout()
plt.show()

# %%
# h

variables = ['Outstate', 'Room.Board', 'Books', 'Personal']
titles = ["Out-of-State Tuition (10 bins)", "Room & Board (15 bins)", "Books (20 bins)", "Personal Spending (25 bins)"]
bins = [10, 15, 20, 25]
x_labels = ["Out-of-State Tuition ($)", "Room & Board Costs ($)", "Book Costs ($)", "Personal Spending ($)"]

fig, axes = plt.subplots(2, 2, figsize=(10, 8))

for i, ax in enumerate(axes.flatten()):
    college[variables[i]].plot.hist(bins=bins[i], ax=ax, title=titles[i])
    ax.set_xlabel(x_labels[i])
    ax.set_ylabel("Number of Schools")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings
#
# These insights highlight variations in costs, popularity, and outcomes across institutions. The patterns suggest that certain factors, such as school type (private vs. public) and elite status, influence both costs and enrollment figures, which could impact accessibility and affordability for students.
#
# #### Out-of-State Tuition
#
# The Out-of-state tuition graph varies greatly and has a peak in the mid-range (around 7,500–12,500 dollars).
#
# This suggest that most schools charge a significantly high out-of-state tuition, which could impact the affordability for non-resident students, particularly at elite or private institutions.
#
# #### Room & Board
#
# Room and board costs are shown to generally land between $3,500 and $5,500. This shows a somewhat standardized cost for room and board across all schools, which could reflect on both stable housing and food prizes as being affordable.
#
# #### Book Costs
#
# Book costs are strongly right-skewed (meaning that most data lands on the left side of the graph), with most institutions reporting expenses below $500 a year, but a few outliers spend significantly more.
#
# This variation might be due to differences in programs and required materials - for instance, institutions offering specialized or resource-heavy programs could have higher book costs.
#
# #### Personal Spending
#
# Personal spending is also right-skewed, with a high frequency of schools reporting around $1,000 in personal expenses, but some outliers reporting up to $7,000. The outliers might be due to differences in costs between urban and rural schools, where prize of housing and other expenses can differ greatly.
#
#
# #### Relationship Between Costs and Elite Status
#
# Elite institutions (those with a higher percentage of students from the top 10% of their high school class) tend to have higher out-of-state tuition costs, as observed in previous boxplots. This suggests that elite institutions may use higher tuition as a premium, reflecting their reputation or exclusivity. This might be a factor in increasing the gap between the richer classes with the less fortunate ones, since cost could dictate whether or not you get educated.
#
# Elite institutions may also have higher personal spending expectations, either due to campus amenities or due to their locations in urban areas, which often have a higher cost of living.
#
# ### Conclusion
#
# These insights shows us that costs associated with higher education vary widely across institutions, with elite and private institutions typically charging higher tuition and possibly influencing other costs. Patterns in personal and book spending also suggest that these expenses may depend on institutional characteristics, such as program offerings or location. These cost differences could impact student access and affordability, especially for those attending elite or out-of-state institutions. It is this authors opinion that education should be free, and that gatekeeping "higher education" behind a paywall only widens the gap between the classes.
